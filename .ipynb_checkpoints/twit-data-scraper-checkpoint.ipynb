# %%
import tweepy, config, json, time
import pandas as pd

def twit_client():
    ''' Authenticate and create instance of twitter client. '''
    print("Starting authentication.")
    client = tweepy.Client(
        bearer_token = config.bearer_token,
        consumer_key = config.api_key,
        consumer_secret = config.api_key_secret,
        access_token = config.access_token,
        access_token_secret = config.access_token_secret,
    )
    print("Authentication complete.")
    return client

def get_user_info(lst_author_id):
    ''' Get twitter usernames corresponding to their user ids.'''
    client = twit_client()
    user_name = []
    for author_id in lst_author_id:
        user_name.append(client.get_user(author_id = author_id))
    return user

def search_tweets(str_query, int_max_results, list_expansions, list_tweet_fields, 
                  list_user_fields,paginator_limit):
    ''' Scrape tweets based on certain filters and parameters. '''
    print("Starting tweet retrieval.")
    paginator = tweepy.Paginator
    client = twit_client()
    search_results = []
    counter = 0
    for iterator in paginator(client.search_recent_tweets,
                              query = str_query, 
                              max_results = int_max_results,
                              expansions = list_expansions,
                              tweet_fields = list_tweet_fields,
                              user_fields = list_user_fields).flatten(
                              limit = paginator_limit):
        counter += 1   
        print("Retrieval loop number: {number}%".format(
            number = round((counter/paginator_limit)*100,2)),end='',flush=True)        
#         time.sleep(0.3)
        search_results.append(iterator)
        print('\r', end='')
    print('\r', end='')
    print("Tweet retrieval complete.")
#     print(search_results)
    return search_results

def tweets_to_file(fname, search_results):
    print("Starting write to file, {fname}.".format(fname=fname))
    with open(fname,'w') as fhandle:
        for tweet in search_results:
            tmp_dict  = {
                "tweet_id" : tweet.id,
                "tweet_text" : tweet.text,
                "tweet_time" : str(tweet.created_at),
                "tweet_author_id" : tweet.author_id,
#                 "tweet_username" : tweet.username,
                "tweet_language" : tweet.lang,
                "tweet_public_metrics" : tweet.public_metrics,
                "tweet_source" : tweet.source
            }
            json.dump(tmp_dict, fhandle)
            fhandle.write("\n")
    print("Write to file, {fname}, completed.".format(fname=fname))
    return 0

def tweetfile_2_dataframe(fname):
    print("Converting file to dataframe.")
    with open(fname, 'r') as fhandle:
        lines = fhandle.readlines()
        dict_lst = []   
        for line in lines:
            organized_dict = {}
            tmp_dict = json.loads(line.strip())
            for key in tmp_dict:
                if key == 'tweet_public_metrics':
                    for key2 in tmp_dict['tweet_public_metrics']:
                        organized_dict[key2] = tmp_dict['tweet_public_metrics'][key2]
                else:
                    organized_dict[key] = tmp_dict[key]
            dict_lst.append(organized_dict)
    df = pd.DataFrame(dict_lst)
    print("File to dataframe conversion completed.")
    return df

def main():
    # Application Options
    fetch_new_data = 'y' # value 'y' for yes
    write_data_to_file = 'y'
    read_from_file = 'y' # value 'y' for yes
    fname = 'test'
    # Fetch new data
    if fetch_new_data == 'y':
        # Parameters
        str_query_1 = '((Roe Wade) OR (roe wade)) -is:retweet -is:reply -is:quote'
        int_max_results = 10
        list_expansions = ['author_id','entities.mentions.username'] 
        list_tweet_fields = ['created_at','lang','public_metrics', 'source','id']
        list_user_fields = ['username']
        paginator_limit = 10
        # Retrieve tweets as a list
        search_results = search_tweets(
            str_query_1, 
            int_max_results, 
            list_expansions, 
            list_tweet_fields,
            list_user_fields,
            paginator_limit
        )
        # Write tweet data to file
    if write_data_to_file == 'y':
        tweets_to_file(fname, search_results)
    # Read data from file
    if read_from_file == 'y':
        # Import file as pandas data frame
        df = tweetfile_2_dataframe(fname)
        print(df)
    
if __name__ == "__main__":
    main()
# Out:
# Starting tweet retrieval.
# Starting authentication.
# Authentication complete.
# Tweet retrieval complete.0.0%
# Starting write to file, test.
# Write to file, test, completed.
# Converting file to dataframe.
# File to dataframe conversion completed.
#               tweet_id                                         tweet_text  \
# 0  1545060654490365953  Supreme Court Justice Clarence Thomas has ties...
# 1  1545060640238096387  Supreme Court Justice Clarence Thomas has ties...
# 2  1545060627428696069  Supreme Court Justices Have Been Praying With ...
# 3  1545060618952003586  Supreme Court Justices Have Been Praying With ...
# 4  1545060551050641408  How The Supreme Court Killed Roe v. Wade https...
# 5  1545060455755837441  "Lets use the energy and passion for women’s i...
# 6  1545060395529879552  Roe v. Wade decision 2022: Republican moms are...
# 7  1545060386424045569  Thanks to the overturning of "Roe v. Wade", I'...
# 8  1545060345021992962  Op-Ed: How IVF could be derailed by abortion r...
# 9  1545060326449618944  Supreme Court Justice Clarence Thomas has ties...
#
#                   tweet_time      tweet_author_id tweet_language  \
# 0  2022-07-07 15:02:20+00:00           2467139815             en
# 1  2022-07-07 15:02:17+00:00  1198296896290209797             en
# 2  2022-07-07 15:02:14+00:00            131168785             en
# 3  2022-07-07 15:02:12+00:00            560678254             en
# 4  2022-07-07 15:01:55+00:00  1544417753385271297             en
# 5  2022-07-07 15:01:33+00:00             18534190             en
# 6  2022-07-07 15:01:18+00:00           1411678987             en
# 7  2022-07-07 15:01:16+00:00             19280985             en
# 8  2022-07-07 15:01:06+00:00             17825891             en
# 9  2022-07-07 15:01:02+00:00            572854430             en
#
#    retweet_count  reply_count  like_count  quote_count        tweet_source
# 0              0            0           0            0  Twitter for iPhone
# 1              0            0           0            0     Twitter Web App
# 2              0            0           0            0     Twitter Web App
# 3              0            0           0            0     Twitter Web App
# 4              0            0           0            0     Twitter Web App
# 5              0            0           0            0      Hootsuite Inc.
# 6              0            0           0            0  Twitter for iPhone
# 7              0            0           0            0     Twitter Web App
# 8              0            0           0            0              Buffer
# 9              0            0           0            0     Twitter Web App
